# %% [markdown]
# # Store project  : saison 1
#
# Voici un petit projet sur un dataset de vente random afin de vous exercer à manpuler les dates.
# On va donc voir petit à petit comment manipuler ces dates.
# ___________________________________________

# %%
#Import vos lib
import warnings
warnings.filterwarnings("ignore")

# %%
#Loader votre dataset
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
#Afficher les information du dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null datetime64[ns]
# Ship Date        9994 non-null datetime64[ns]
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
#Afficher les statistiques descriptives
# Out:
#              Row ID        Order ID       Ship Mode Customer ID  \
# count   9994.000000            9994            9994        9994
# unique          NaN            5009               4         793
# top             NaN  CA-2017-100111  Standard Class    WB-21850
# freq            NaN              14            5968          37
# mean    4997.500000             NaN             NaN         NaN
# std     2885.163629             NaN             NaN         NaN
# min        1.000000             NaN             NaN         NaN
# 25%     2499.250000             NaN             NaN         NaN
# 50%     4997.500000             NaN             NaN         NaN
# 75%     7495.750000             NaN             NaN         NaN
# max     9994.000000             NaN             NaN         NaN
#
#         Customer Name   Segment        Country           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
# mean              NaN       NaN            NaN            NaN         NaN
# std               NaN       NaN            NaN            NaN         NaN
# min               NaN       NaN            NaN            NaN         NaN
# 25%               NaN       NaN            NaN            NaN         NaN
# 50%               NaN       NaN            NaN            NaN         NaN
# 75%               NaN       NaN            NaN            NaN         NaN
# max               NaN       NaN            NaN            NaN         NaN
#
#          Postal Code Region       Product ID         Category Sub-Category  \
# count    9994.000000   9994             9994             9994         9994
# unique           NaN      4             1862                3           17
# top              NaN   West  OFF-PA-10001970  Office Supplies      Binders
# freq             NaN   3203               19             6026         1523
# mean    55190.379428    NaN              NaN              NaN          NaN
# std     32063.693350    NaN              NaN              NaN          NaN
# min      1040.000000    NaN              NaN              NaN          NaN
# 25%     23223.000000    NaN              NaN              NaN          NaN
# 50%     56430.500000    NaN              NaN              NaN          NaN
# 75%     90008.000000    NaN              NaN              NaN          NaN
# max     99301.000000    NaN              NaN              NaN          NaN
#
#            Product Name         Sales     Quantity     Discount       Profit
# count              9994   9994.000000  9994.000000  9994.000000  9994.000000
# unique             1850           NaN          NaN          NaN          NaN
# top     Staple envelope           NaN          NaN          NaN          NaN
# freq                 48           NaN          NaN          NaN          NaN
# mean                NaN    229.858001     3.789574     0.156203    28.656896
# std                 NaN    623.245101     2.225110     0.206452   234.260108
# min                 NaN      0.444000     1.000000     0.000000 -6599.978000
# 25%                 NaN     17.280000     2.000000     0.000000     1.728750
# 50%                 NaN     54.490000     3.000000     0.200000     8.666500
# 75%                 NaN    209.940000     5.000000     0.200000    29.364000
# max                 NaN  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# _________________________________
#
# ## Focus sur les catégories

# %%
#Afficher un dataset ne contenant que la catégorie Furniture
#Afficher ses stats
# Out:
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  2121.000000   2121.000000  2121.000000  2121.000000  2121.000000
# mean   5041.643564  55726.556341   349.834887     3.785007     0.173923
# std    2885.740258  32261.888225   503.179145     2.251620     0.181547
# min       1.000000   1040.000000     1.892000     1.000000     0.000000
# 25%    2568.000000  22801.000000    47.040000     2.000000     0.000000
# 50%    5145.000000  60505.000000   182.220000     3.000000     0.200000
# 75%    7534.000000  90032.000000   435.168000     5.000000     0.300000
# max    9991.000000  99301.000000  4416.174000    14.000000     0.700000
#
#             Profit
# count  2121.000000
# mean      8.699327
# std     136.049246
# min   -1862.312400
# 25%     -12.849000
# 50%       7.774800
# 75%      33.726600
# max    1013.127000

# %%
#Afficher un dataset ne contenant que la catégorie Technology
#Afficher ses stats
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  1847.000000   1847.000000   1847.000000  1847.000000  1847.000000
# mean   5003.331890  55551.572279    452.709276     3.756903     0.132323
# std    2900.259785  31896.118284   1108.655848     2.216828     0.141575
# min       8.000000   1841.000000      0.990000     1.000000     0.000000
# 25%    2513.000000  23392.000000     68.016000     2.000000     0.000000
# 50%    5054.000000  59601.000000    166.160000     3.000000     0.200000
# 75%    7546.500000  90008.000000    448.534000     5.000000     0.200000
# max    9992.000000  99207.000000  22638.480000    14.000000     0.700000
#
#             Profit
# count  1847.000000
# mean     78.752002
# std     428.816633
# min   -6599.978000
# 25%       5.203650
# 50%      25.018200
# 75%      74.894600
# max    8399.976000

# %%
#Afficher la date la plus ancienne pour la catégorie furniture
# Out:
# Timestamp('2014-01-06 00:00:00')

# %%
#Afficher la date la plus récente pour la catégorie furniture
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
#Compter le nombre de jours présent dans le dataset
# Out:
# Il y a donc 1454 jours de données dans le dataset

# %%
#Vérifier que c'est pareil pour la catégorie Technology
# Out:
# Il y a donc 1454 jours de données dans le dataset

# %% [markdown]
# _________________________________
#
# ## Mini data preprocessing

# %%
#Construire un dataframe uniquement composé de la date et de la catégorie furniture
# Out:
#    Order Date      Sales
# 0  2016-11-08   261.9600
# 1  2016-11-08   731.9400
# 3  2015-10-11   957.5775
# 5  2014-06-09    48.8600
# 10 2014-06-09  1706.1840

# %%
#Trier votre nouveau dataset par date croissante
# Out:
#      Order Date     Sales
# 7474 2014-01-06  2573.820
# 7660 2014-01-07    76.728
# 866  2014-01-10    51.940
# 716  2014-01-11     9.940
# 2978 2014-01-13   545.940

# %%
#Vérifier que le dataset ne possède pas d'éléments nuls
# Out:
# Order Date    0
# Sales         0
# dtype: int64

# %%
#Réindexer votre dataset pour que les indices "suivent les dates"
#C-a-d que l'indice n°1 soit la première date, l'indice n°2 la deuxième ...
# Out:
#   Order Date     Sales
# 0 2014-01-06  2573.820
# 1 2014-01-07    76.728
# 2 2014-01-10    51.940
# 3 2014-01-11     9.940
# 4 2014-01-13   879.939

# %%
#Maintenant mettre les date comme indice / meta colonne
# Out:
#                Sales
# Order Date
# 2014-01-06  2573.820
# 2014-01-07    76.728
# 2014-01-10    51.940
# 2014-01-11     9.940
# 2014-01-13   879.939

# %% [markdown]
# **Il est parfois difficile de travailler avec des données datetime. Nous utiliserons plutôt les valeurs des ventes quotidiennes moyennes pour un mois et le début de chaque mois comme horodatage.**

# %%
#Afficher les ventes moyenne pour chaque mois 
#L'exemple ci-dessous ne montre que les 5premiers mois 
#Vous devez le faire pour le dataset en entier
# Out:
# Order Date
# 2014-01-01    480.194231
# 2014-02-01    367.931600
# 2014-03-01    857.291529
# 2014-04-01    567.488357
# 2014-05-01    432.049188
# Freq: MS, Name: Sales, dtype: float64

# %%
#Regarder le chiffre moyen par mois sur l'année 2017
# Out:
# Order Date
# 2017-01-01     397.602133
# 2017-02-01     528.179800
# 2017-03-01     544.672240
# 2017-04-01     453.297905
# 2017-05-01     678.302328
# 2017-06-01     826.460291
# 2017-07-01     562.524857
# 2017-08-01     857.881889
# 2017-09-01    1209.508583
# 2017-10-01     875.362728
# 2017-11-01    1277.817759
# 2017-12-01    1256.298672
# Freq: MS, Name: Sales, dtype: float64

# %%
#Donner le chiffre d'affaire moyen par mois de l'année 2017
# Out:
# Le chiffre moyen mensuel l'année 2017 est de 788.99€

# %% [markdown]
# ___________________________________
# ## Visualisation
# ### Variables catégoriques

# %%
#Ploter les variables catégoriques

# %% [markdown]
# ### Dates

# %%
#Afficher les ventes moyenne pour chaque mois
#Que remarquez vous ?

# %%
#Faite de meme avec la catégorie Technology 
#Que remarquez vous ?

# %%
#Décomposer grace à la librairie statmodels votre série en 3 sous serie 
#Trouver la fonction qui vous permet d'extraire de votre série 
#la tendance, les saisonnalités et le bruit

# %%
#Faire la décomposition pour la catégorie trechnology 
#Cela confirme bien ce que vous pensiez ?
